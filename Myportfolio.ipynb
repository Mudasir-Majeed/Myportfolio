# %%
import streamlit as st

st.title("My Portfolio")
st.sidebar.title("Navigation")
page = st.sidebar.radio("Go to", ["Home", "About", "Projects", "Contact"])

if page == "Home":
    st.write("Welcome to my portfolio!")
elif page == "About":
    st.write("I am a Python developer.")
elif page == "Projects":
    st.write("- Chatbot\n- Clinic Website")
elif page == "Contact":
    st.text_input("Your Name")
    st.text_area("Your Message")
    st.button("Send")
# Out:
# 2025-05-02 11:52:55.137 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-02 11:52:55.837
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\hp\AppData\Roaming\Python\Python312\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2025-05-02 11:52:55.837 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-02 11:52:55.852 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-02 11:52:55.852 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-02 11:52:55.852 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-02 11:52:55.852 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-02 11:52:55.852 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-02 11:52:55.852 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-02 11:52:55.868 Session state does not function when running a script without `streamlit run`
# 2025-05-02 11:52:55.868 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-02 11:52:55.881 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-02 11:52:55.881 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-02 11:52:55.881 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
